# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ### <font color='navy'> Simulación de procesos financieros.
#
# **Nombres:** Marco Antonio Sánchez Covarrubias y Esteban Márquez Delgado
#
# **Fecha:** 07 de octubre del 2021.
#
# **Expediente** : if720268 e if700637
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Link Github**: https://github.com/MarcoSC08/Tarea6_MASanchez_EMarquez
#
# # Tarea 6: Clase 10

# %% [markdown]
# ## Enunciado de tarea
# > Partiendo que se desea generar variables aleatorias para la siguiente función de densidad
# $$f(x)=30(x^2-2x^3+x^4)$$
# Responda los siguientes literales:

# %% [markdown]
# ### Ejercicio 1:
# 1. Usar como función que mayora a $f(x)$ a $t(x)=a \sin(\pi x)$ donde a es el máximo de la función $f(x)$ y graficarlas en una misma gráfica, para validar que en realidad si cumple la condición $t(x)\geq f(x)$.

# %% [markdown]
# Código de solución estudiante 1

# %%
import numpy as np
from scipy import optimize
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from scipy.stats import erlang
from scipy import optimize
from scipy.stats import beta
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import scipy.optimize as opt
import math

# %%
# Función objetivo 
f = lambda x:30*(x**2-2*x**3+x**4)
# Máximo de la función f
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False)) #Función a maximizar

# Función t -> Función constante
t = lambda x: max_f*np.sin(np.pi*x) # función constante

x = np.arange(0,1,0.01)  # Rango gráfico funciones
print('Funciones, punto máximo:',max_f)
# Gráficas de las funciones
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()
plt.show()
# Out:
# Funciones, punto máximo: [1.875]

# %% [markdown]
# Código de solución estudiante 2

# %%
# Código de solución estudiante 2 
f = lambda x: 30 * (x**2 - 2 * x**3 + x**4) #Función objetivo
max_f = f(optimize.fmin(lambda x:-f(x), 0, disp=False))#Máx. de f
t = lambda x: max_f * np.sin(np.pi*x) #Función de validación
x = np.arange(0, 1.02, .02) #Rango

# Estética de Gráfico
plt.style.use('dark_background')
plt.rc('grid', linestyle="--", color='gray')
plt.figure(figsize = (12, 8))
plt.plot(x,f(x),label='Función de densidad f(x)', color='white', linewidth=3, linestyle='dotted')
plt.plot(x,t(x),label='Funcion validación t(x)', color='orange', linewidth=1)
plt.title('Función t(x) ≥ f(x)', fontsize = 18)
plt.ylabel('Probabilidad', fontsize= 13)
plt.xlabel('x', fontsize= 13)
plt.legend()

# %% [markdown]
# ### Respuesta planteada en el ejercicio usando (markdown)
# La **función de validación** *es mayor a la* **función de densidad** a excepción del punto en el cual se tocan, el máximo de ambas funciones.

# %% [markdown]
# ### Ejercicio 2
# 2. Encontrar la función de densidad $g(x)$ según lo visto en clase. Reportar todos los cálculos realizados para encontrar dicha función usando Markdown (Latex).

# %% [markdown]
# Código de solución estudiante 1

# %% [markdown]
# #### Código de solución estudiante 1
# $$g(x)=\frac{t(x)}{c}$$
#
# $$f(x)=30(x^2-2x^3+x^4)$$
#
# $$t(x)=a \sin(\pi x)$$
#
# $$a=max(f(x))$$
#
# $$c=\int_{0}^{1}a sin(\pi x)dx$$
# Sacando a
#
# $$c=max(f(x))\int_{0}^{1} sin(\pi x)dx$$
# $$c= max(f(x))* [-\frac{cos(\pi y)}{\pi} ]_{0}^{1} = \frac{2}{\pi}max(f(x))$$
#
# $$g(x)=\frac{t(x)}{c}=\frac{max(f(x)) \sin(\pi x)}{\frac{2}{\pi}max(f(x))}=\frac{\pi sin(\pi x)}{2}$$

# %% [markdown]
# #### Código de solución estudiante 2
# Si $t(x) = a \sin(\pi x)$ y $c = \int_{0}^{1} t(x)$ entonces
# $$c = \int_{0}^{1} a \sin(\pi x) dx = a \int_{0}^{1} \sin(u) \frac{du}{\pi} = \frac{a}{\pi} \int_{0}^{1} \sin(u) du =$$
#
#
# $$\frac{a}{\pi} [-\cos(u)]_{0}^{1} = \frac{a}{\pi} [-\cos(\pi x)]_{0}^{1} = \frac{a}{\pi} [-\cos(\pi) + \cos(0)] = \frac{a}{\pi} [-\cos(\pi) + \cos(0)] = \frac{a}{\pi} [-(-1) + 1]= \frac{2a}{\pi}$$
#
#
# $$g(x) = \frac{t(x)}{c}$$

# %% [markdown]
# Se encuentra la función de densidad g(x) al obtener c mediante la integración de t(x) en el rango de 0 a 1 para sustituir de la sig. manera: $$g(x) = \frac{\pi \sin(\pi x)}{2}$$

# %% [markdown]
# ### Ejercicio 3
# 3. Usar la función encontrada en el punto 2 y utilizar el método de la transformada inversa visto en la clase 9, para generar variables aleatorias que sigan la distribución $g(x)$. **Nota:** Recuerde que el método de la transformada inversa funciona con la distribución de probabilidad acumulada y no con su densidad. Nuevamente similar al punto anterior reportar todos los cálculos usando Markdown (Latex).

# %% [markdown]
# Código de solución estudiante 1

# %% [markdown]
# #### Código de solución estudiante 1
# $$G(x)= \int_{0}^{x} g(x)dx = \frac{1}{2} \int_{0}^{x} sin(\pi x)$$
#
# $$G(x)=-\frac{1}{2} [cos(\pi x)]^{x}_{0}= \frac{1}{2} (1-cos(\pi x))$$
#
# $$U= \frac{1}{2} (1-cos(\pi x))$$
#
# Despejando...
#
# $$x=2U=(1-cos(\pi x)$$
#
# $$cos(\pi x)+2U =1 $$
#
# $$cos(\pi x)=1 - 2U  $$
#
# $$\pi x= arcos(1 - 2U)  $$
#
# $$x= \frac{arcos(1 - 2U)}{\pi }  $$

# %% [markdown]
# #### Código de solución estudiante 2
# Primero debemos de integrar por sustitución g(x):
# $$G(x) = \int_{0}^{x}g(x) = \int_{0}^{x}\frac{\pi \sin(\pi x)}{2} = -\frac{1}{2}[cos(\pi x)]_{0}^{x}= -\frac{1}{2}cos(\pi x) + \frac{1}{2}$$
#
# Habiendo obtenido la transformada inversa, despejamos para x:
# $$ G(x) = -\frac{1}{2}cos(\pi x) + \frac{1}{2}= U ∴ -2U + 1 = cos(\pi x) $$
# $$ x = \frac{cos^{-1}(-2U +1)}{\pi}$$

# %% [markdown]
# ### Respuesta planteada en el ejercicio usando (markdown)
# $$ x = \frac{cos^{-1}(-2U +1)}{\pi}$$

# %% [markdown]
# ### Ejercicio 4
# 4. Según el punto 3, generar 10000 puntos aleatorios que sigan la distribución $g(x)$ y comparar con su histograma para validar que los puntos generados siguen la distribución deseada. El resultado debe ser como sigue:
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# Código de solución estudiante 1

# %%
# Código de solución estudiante 1
def m_alea(N):
    u =np.random.uniform(0,2/np.pi,N)#ciclo completo 2pi
    y=list(map(lambda x: (1/np.pi)*np.arccos(1-np.pi*u[x]),range(N)))
    return y

# %%
N = 10**4
def plot_hist(N):
    r1=m_alea(N)
    y,x,_=plt.hist(r1, bins=50,density=True)
    y2 =(np.pi*np.sin(np.pi*x))/2 #-(1/np.pi)*(np.cos(np.pi*x))+(1/np.pi)
    plt.plot(x,y2,'r-')
    #(1/np.pi)*np.arccos(1-np.pi*u[x]),range(N)))
    plt.show()                    

plot_hist(N)

# %% [markdown]
# #### Código de solución estudiante 2

# %%
# Código de solución estudiante 2
g = lambda x: ((np.pi)*(np.sin(np.pi*x)))/2 # densidad
G_Inv = lambda u: ((np.arccos(2*(1/2-u)))/np.pi) # transformada inversa
n = 10000 # n muestras

u = np.random.rand(n) # valores aleatorios sobre u
g_val = G_Inv(u)   # evaluación de transformada inversa sobre u
x = np.arange(0,1,0.01) # valores aleatorios sobre x
g_den = g(x)        # evaluación de funcion de densidad sobre x
 
#Estética de histograma
plt.rc('grid', linestyle="--", color='gray') 
plt.figure(figsize = (12, 8))
plt.hist(g_val, bins = 50, density = True, color='r') 
plt.plot(x, g_den, color="w", linewidth=3)
plt.xlabel("Valores aleatorios")
plt.ylabel("Probabilidad")
plt.title("Transformada inversa")
# Out:
# Text(0.5, 1.0, 'Transformada inversa')

# %% [markdown]
# Como se ilustró en clase, a partir de t(x) obtenemos g(x) para graficar un histograma sobre la distribución de la transformada inversa G(x).

# %% [markdown]
# ### Ejercicio 5
# 5. Genere 500 puntos aleatorios usando el método de aceptación y rechazo y las funciones $f(x)$ y $t(x)$ para validar que todos los cálculos anteriores están correctamente realizados. El resultado debe de ser como sigue:
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# Código de solución estudiante 1

# %%
def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo',
                 t:'función mayor f'):

    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'om') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'oc') 
     for i in range(len(R1))]
                
    plt.show()
    
    x = [R1[i] for i in range(len(R1)) if condition[i]]
    return x

# %%
# Ilustración del método de aceptación y rechazo cuando se toma t(x) constante

f = lambda x:30*(x**2-2*x**3+x**4)# Función objetivo 
# Máximo de la función f
max_f = f(optimize.fmin(lambda x:-f(x),0,disp=False)) 
# Función t 
t = lambda x: max_f*np.sin(np.pi*x) # función t en este caso no es constante
x = np.arange(0,1,0.01)  # Rango donde se graficará las funciones
print('El máximo de f es:',max_f)

# Gráficas de las funciones
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

# Validación del método
N = 500 # número de puntos a simular
#t(x) constante solo es necesario generar valores aleatorios U~(0,1)
R2 = np.random.rand(N)
R1 = np.arccos(1-2*np.random.rand(N))/np.pi

x_s=Acep_rechazo(R2,R1,f,t)
# Out:
# El máximo de f es: [1.875]

# %% [markdown]
# #### Código de solución estudiante 2

# %%
# Código de solución estudiante 2
# Función de aceptación y rechazo usando compresión de listas
def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
    R1 = np.random.rand(N) #Valores aleatorios sobre R1
    f_x = f(R1) #Función objetivo
    t_x = t(R1) #Función de validación
    condition = R2*t_x <=f_x #Para los valores de R2 distribuidos dentro de la función de validación y objetivo
    [plt.plot(R1[i],R2[i]*t_x[i],'*y') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'or') \
    for i in range(len(R1))] #Valores aleatorios
    plt.show()
    x = [R1[i] for i in range(len(R1)) if condition[i]]
    return x

# Parámetros 
N = 500  # 500 puntos aleatorios con el método aceptación y rechazo
x =np.arange(0,1.02,0.02) # Vector donde se graficará la función validación
f = lambda x: 30*(x**2 -2 * x**3 + x**4) # Función de densidad
a = f(optimize.fmin(lambda x:-f(x), 0, disp=False)) # Max. de la función
print('El máximo de f es:',a)

#Estética de gráfico y puntos de función Acep_rechazo
plt.figure(figsize = (14, 8))
plt.plot(x,f(x))
t = lambda x: a * np.sin(np.pi*x) #Pulso senoidal
plt.plot(x,f(x),'m',label='$f(x)=30(x^2-2x^3+x^4)$', color='white', linewidth=3, linestyle='dotted')
plt.plot(x,t(x),'g',label='$t(x)=a *\sin(\pi x)$', color='orange', linewidth=1)
plt.legend()
plt.title("Gráfica de g(x)",fontsize=18)
plt.xlabel('x',fontsize=14)
plt.ylabel('Probabilidad',fontsize=14)
R1 = np.random.rand(N) #Se genera R1 y R2 como una distribución uniforme con n puntos
R2 = np.random.rand(N)
r=Acep_rechazo(R2,R1,f,t) #Vector de variables aleatorias
plt.show()
# Out:
# El máximo de f es: [1.875]

# %% [markdown]
# Se aplicó el método de aceptación y rechazo, se obtiene que se aceptan ≈ 70% de los valores. Los puntos aceptados son aquellos denotados con estrellas y los rechazados como puntos rojos. Esto fue posible a través de la función de validación $t(x)=a *\sin(\pi x)$ donde $a$ es el valor máximo cuya intersección es con la curva $f(x)=30(x^2-2x^3+x^4)$.

# %% [markdown]
# ### Ejercicio 6
# 6. Comparar el porcentaje de puntos de aceptación cuando se usa $t(x)$ constante y $t(x)$ un pulso senoidal. Concluir

# %% [markdown]
# Código de solución estudiante 1

# %%
# Código de solución estudiante 1

def Acep_rechazo2(R2:'Variables distruidas U~U(0,1)', # Función de aceptación y rechazo usando compresión de listas de pulso senoidal
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    cont=np.asarray([1 if condition[i] else 0 for i in range(len(R1))]).sum()
    return cont

ans=(Acep_rechazo2(R2,R1,f,t)/len(R1))*100
"El porcentaje de puntos de aceptación es de:" , ans, "con punto senoidal"
# Out:
# ('El porcentaje de puntos de aceptación es de:', 73.6, 'con punto senoidal')

# %%
# Función de aceptación y rechazo usando compresión de listas de t(x) constante
R2_2=np.random.rand(N)
R1_2=np.random.rand(N)
ans2=(Acep_rechazo2(R2_2,R1_2,f,t)/len(R1))*100
"El porcentaje de puntos de aceptación es de:" , ans2, "con constante"
# Out:
# ('El porcentaje de puntos de aceptación es de:', 68.0, 'con constante')

# %%
# grafica de la aceptacion y rechazo

plt.figure(figsize=[8,6])
plt.title('Gráfica Aceptación y Rechazo para $t(x)=a$',fontsize=18)
plt.plot(x,f(x), label='$f(x)=30(x^2-2x^3+x^4)$')
t = lambda x: a*np.ones([len(x)]) 
plt.plot(x,t(x),label='$t(x)=a$') 
plt.legend(loc="best");


# Simulacion del metodo
N = 500 
R2 = np.random.rand(N)
R1 = np.random.uniform(0,1, size=N)
x_a = Acep_rechazo(R2,R1,f,t)
print(f'El porcentaje aceptado para la función de senoidal es {len(x_s)/N}')
print(f'El porcentaje aceptado para la función constante es {len(x_a)/N}')
# Out:
# El porcentaje aceptado para la función de senoidal es 0.836
# El porcentaje aceptado para la función constante es 0.578

# %% [markdown]
# #### Código de solución estudiante 2

# %%
### Estética del gráfico
plt.figure(figsize=[14,8])
plt.title('Método de Aceptación y Rechazo $f(x)=30(x^2-2x^3+x^4)$  y  $t(x)=a$',fontsize=18)
plt.xlabel('x',fontsize=14)
plt.ylabel('Probabilidad',fontsize=14)
t = lambda x: a*np.ones([len(x)]) #Función t(x) constante sobre valor max. a
#Graficar función de densidad f(x) y función t(x) constante
plt.plot(x,f(x), label='$f(x)=30(x^2-2x^3+x^4)$', color='white', linewidth=3, linestyle='dotted')
plt.plot(x,t(x),label='$t(x)=a$', color='orange', linewidth=2, linestyle='-') #Función de validación constante
plt.legend(loc="best");
N = 500 #n puntos aleatorios
R1 = np.random.rand(N) #Se genera R1 y R2 como una distribución uniforme con n puntos
R2 = np.random.rand(N)
a = Acep_rechazo(R2,R1,f,t)
print(f'Elementos aceptados para pulso senoidal: {len(r)/N}')
print(f'Elementos aceptados para t(x) constante: {len(a)/N}')
# Out:
# Elementos aceptados para pulso senoidal: 0.682
# Elementos aceptados para t(x) constante: 0.576

# %% [markdown]
# Se obtuvo que $a$ es el valor máximo para $f(x)=30(x^2-2x^3+x^4)$. Para este caso, siendo t(x) el pulso senoidal se aceptaron más elementos ($\approx 70\%$) a comparación que cuando se aplico el método con la función constante $a$ ($\approx 57\%$). Aún así, sigue siendo útil tener el punto máximo de la función de densidad como una función constante para aplicar el método.

# %% [markdown]
# ### Ejercicio 7
# 7. Genere una variable aleatoria $X$ a partir de la siguiente PDF
# $$f(x)=20x(1-x)^3$$
# usando el método de aceptación y rechazo

# %% [markdown]
# Código de solución estudiante 1

# %%
# Código de solución estudiante 1
N = 500  # número de puntos
# Función objetivo
f = lambda x: 20*x*(1-x)**3
x = np.arange(0,1,0.01)
plt.plot(x,f(x),'k')

c = float(f(optimize.fmin(lambda x:-f(x),0,disp=False)))#máximo de la función f
print('El máximo de la función es:',c)

t = lambda x: c*np.ones(len(x))
plt.plot(x,f(x),'k')
plt.plot(x,t(x),'b')
R2 = np.random.rand(N)
R1 = np.random.rand(N)
plt.plot(x,f(x),label='f(x)')
plt.plot(x,t(x),label='punto maximo')
plt.legend()
Acep_rechazo(R2,R1,f,t)

plt.show()
# Out:
# El máximo de la función es: 2.109375

# %%
def yes_no(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo',
                 t:'función mayor f'):

    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'om') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'oc') 
     for i in range(len(R1))]
                
    plt.show()
    
    x = [R1[i] for i in range(len(R1)) if condition[i]]
    return x

# %%
# puntos de aceptacion y rechazo

plt.figure(figsize=[8,6])
plt.title('Gráfica Aceptación y Rechazo para $f(x)=20x(1-x)^3$',fontsize=18)
f = lambda x: 20*x*(1-x)**3
a = f(optimize.fmin(lambda x:-f(x), 0, disp=False))
t = lambda x: a*np.ones([len(x)])


plt.plot(x,f(x), label='$f(x)=20x(1-x)^3$')
plt.plot(x,t(x),label='$t(x)=a$')
plt.legend(loc="best");
# Simulacion del metodo

N = 500 
R2 = np.random.rand(N)
R1 = np.random.uniform(0,1, size=N)
V_A = yes_no(R2,R1,f,t)
print(f'La variable aleatoria arroja los siguientes valores: {V_A[:10]}')
# Out:
# La variable aleatoria arroja los siguientes valores: [0.49369669938384086, 0.2748922244529587, 0.519941191347391, 0.5037718433544993, 0.45941482228222896, 0.21932892122216496, 0.4215374053254697, 0.46772779292712174, 0.36929366484624426, 0.1997946509248928]

# %% [markdown]
# #### Código de solución estudiante 2

# %%
def Puntos_Acep(R2:'Variables distribuidas U~U(0,1)', # Función de aceptación y rechazo usando compresión de listas de pulso senoidal
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
    """
    La función regresa los puntos que acepta y realiza el histograma de dichos puntos en f(x) para su validación.
    """
    f_x = f(R1)
    t_x = t(R1)
    condition = R2*t_x <=f_x
    [plt.plot(R1[i], R2[i]*t_x[i], '*y') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i], 'or') for i in range (len(R1))]
    plt.show()
    
    Aceptados = [R1[i] for i in range(len(R1)) if condition[i]]
    return Aceptados

# %%
# Código de solución estudiante 2
f = lambda x: 20*x*(1-x)**3 #Función objetivo
a = f(optimize.fmin(lambda x:-f(x), 0, disp=False)) #Valor máx. de f(x)
N = 500 #N valores
R1 = np.random.rand(N) #Valores aleatorios 
R2 = np.random.rand(N)
t = lambda x: a*np.ones([len(x)])
#Graficar función de densidad f(x) y función t(x)
plt.figure(figsize=[14,8])
plt.plot(x,f(x), label='$f(x)=20x(1-x)^3$',color='white', linewidth=3, linestyle='dotted')
plt.title('Método de Aceptación y Rechazo (Puntos Aceptados) $f(x)=20x(1-x)^3$  y  $t(x)=a$',fontsize=14)
plt.plot(x,t(x),label='$t(x)=a$',color='orange', linewidth=2, linestyle='-')
plt.legend()
plt.grid()
Aceptados=Puntos_Acep(R2,R1,f,t) #llamada del método de aceptación y rechazo:puntos aceptados
print(f'Aquellos aceptados son: {(len(Aceptados))} puntos o {(len(Aceptados)/N)*100}%. Son los siguientes:') #Puntos
# Out:
# Aquellos aceptados son: 243 puntos o 48.6%. Son los siguientes:

# %%
Aceptados
# Out:
# [0.13577304389613754,
#  0.2958662149127801,
#  0.20096884955730632,
#  0.33470468064559156,
#  0.3150960840766983,
#  0.4560881958507754,
#  0.2446435400898147,
#  0.09992776423828409,
#  0.44217552555711936,
#  0.4955172579744598,
#  0.28555461427994,
#  0.03235477504154893,
#  0.3324513935813894,
#  0.26908420964866797,
#  0.12411498346767824,
#  0.19291608523678627,
#  0.6197983814140265,
#  0.33714705972752446,
#  0.1857996596768513,
#  0.2847283856984215,
#  0.529975198204714,
#  0.14799279971762158,
#  0.22707789854444693,
#  0.05601022884191065,
#  0.43029721657632314,
#  0.1847511903841632,
#  0.5141026603291029,
#  0.6150735309030682,
#  0.5195881825064946,
#  0.07324509949089353,
#  0.5941451592495209,
#  0.6423512079311798,
#  0.0751977864258937,
#  0.3342420094312636,
#  0.3695185363774063,
#  0.1971095020123238,
#  0.6905488596653108,
#  0.8701791810755048,
#  0.24927522008335146,
#  0.29754451286993366,
#  0.6814594842501898,
#  0.6648218534420307,
# ...

# %% [markdown]
# ### Ejercicio 8
# 8. Demostrar la validez de la siguiente ecuación
# $$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i$$

# %% [markdown]
# Código de solución estudiante 1

# %% [markdown]
# Sabemos las sig. propiedades de los factoriales: $n!=n(1+n)!$  y  $\frac{n!}{(n+1)!}=\frac{1}{n+1}$ ∴
#
# $$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i =\frac{\frac{n! p ^ {i+1} (1-p)^{n-i+1}}{(i+1)!(n-i+1)!}}{\frac{n!}{i!(n-i)!}p^i(1-p)^{n-i}}$$
#
# desarrollando obtenemos que:
#
# $$\frac{p_{i+1}}{p_i} = \frac{n!p^ip(1-p)^ni!(n-i)!(1-p)^i}{(1-p)^i(1-p)(i+1)!(n-i-1)!n!p^i(1-p)^n}$$
#
# si eliminamos factores comúnes tenemos que:
#
# $$\frac{p_{i+1}}{p_i} =\frac{p(n-i)!}{(1-p)(i+1)!(n-i-1)!}$$
#
# $$p_{i+1} = \frac{n-i}{i+1}\frac{p}{1-p}p_i$$

# %% [markdown]
# Código de solución estudiante 2

# %% [markdown]
# Sabemos las sig. propiedades de los factoriales: $n!=n(1+n)!$  y  $\frac{n!}{(n+1)!}=\frac{1}{n+1}$ ∴
#
# $$p_{i+1}=\frac{n-i}{i+1}\frac{p}{1-p} p_i =\frac{\frac{n! p ^ {i+1} (1-p)^{n-i+1}}{(i+1)!(n-i+1)!}}{\frac{n!}{i!(n-i)!}p^i(1-p)^{n-i}}$$
#
# desarrollando obtenemos que:
#
# $$\frac{p_{i+1}}{p_i} = \frac{n!p^ip(1-p)^ni!(n-i)!(1-p)^i}{(1-p)^i(1-p)(i+1)!(n-i-1)!n!p^i(1-p)^n}$$
#
# si eliminamos factores comúnes tenemos que:
#
# $$\frac{p_{i+1}}{p_i} =\frac{p(n-i)!}{(1-p)(i+1)!(n-i-1)!}$$
#
# $$p_{i+1} = \frac{n-i}{i+1}\frac{p}{1-p}p_i$$
#
#
# Mediante la programacion vectorizada que es más eficiente y sencilla de programar podemos aprovechar las ecuaciones recursivas
# para aprovechar los valores que se han obtenido y utilizarlos según nos sea conveniente.

# %% [markdown]
# ### Ejercicio 9
# 9. Seguir un procedimiento similar al mostrado cuando se generó una distribución binomial, pero en esta caso genere un código que genere variables aletorias Poisson cuya función de distribución de probabilidad esta dada por:
# $$P(k,\lambda)=\frac{e^{-\lambda}(\lambda)^k}{k!}$$
#
# Demuestre matemáticamente que
#  $$P(k+1)=\frac{\lambda}{k+1}P(k)$$
#  y a partir de esta relación genere variables aletorias que distribuyen poisson usando el método de la transformada inversa.

# %% [markdown]
# Código de solución estudiante 1

# %% [markdown]
# >si:
# $$P(k+1) = \frac{\lambda}{K+1}P(k)$$
# > Entonces:
# $$\frac{P(k+1)}{P(k)} = \frac{\lambda}{k+1}$$
# > en términos de $P(k)$:
# $$\frac{P(k+1)}{P(k)} = \frac{\frac{e^{-\lambda}(\lambda)^{k+1}}{(k+1)!}}{\frac{e^{-\lambda}(\lambda)^k}{k!}}$$
# > Mediante el uso de la propiedad $$\frac{k!}{(k+1)!}=\frac{1}{k+1}$$
# $$\frac{P(k+1)}{P(k)} = \frac{\lambda^{k+1}k!}{\lambda^{k}(k+1)!} = \frac{\lambda}{k+1}$$
# Para obtener finalmente que: $$P(k+1) = \frac{\lambda}{k+1}P(k)$$

# %% [markdown]
# Código de solución estudiante 2

# %% [markdown]
# #### Código de solución estudiante 2
# >si:
# $$P(k+1) = \frac{\lambda}{K+1}P(k)$$
# > Entonces:
# $$\frac{P(k+1)}{P(k)} = \frac{\lambda}{k+1}$$
# > en términos de $P(k)$:
# $$\frac{P(k+1)}{P(k)} = \frac{\frac{e^{-\lambda}(\lambda)^{k+1}}{(k+1)!}}{\frac{e^{-\lambda}(\lambda)^k}{k!}}$$
# > Mediante el uso de la propiedad $$\frac{k!}{(k+1)!}=\frac{1}{k+1}$$
# $$\frac{P(k+1)}{P(k)} = \frac{\lambda^{k+1}k!}{\lambda^{k}(k+1)!} = \frac{\lambda}{k+1}$$
# Para obtener finalmente que: $$P(k+1) = \frac{\lambda}{k+1}P(k)$$

# %%
###Función de Poisson de distribución acum.
def dist_acum_poisson(L:"Parámetro de media y varianza",n:"n-esimo término"): 
    "Función acum. de dist. de Poisson"
    vector = np.zeros(n) #Vector de 0s para su llenado
    vector[0] = (np.exp(-L)) #condición inicial
    def llenar_vector(i):
        nonlocal vector #Para el llenao de vector no interno a la función
        vector[i+1] = (L*vector[i])/(i+1) #Llenado iterativo de vector 
    [llenar_vector(i) for i in range(n-1)] #Compresión de listas
    return vector.cumsum() #Función acumulada
def Gen_distr_discreta(p_acum: 'P.Acum. de la distribución',
                       N: 'N Números aleatorios'):
    U =np.random.rand(N)
    v = [sum([1 for p in p_acum if p < ui ])  for ui in U]
    return v
### Función para plotear el histograma de la función de distribución
def plot_histogram_discrete(distribucion:'distribución por histograma',
                            label:'label'):
    plt.figure(figsize=[14,8])
    y,x = np.histogram(distribucion,bins = len(set(distribucion))) 
    plt.bar(list(set(distribucion)),y,label=label, color='darkblue')
    plt.legend()
    plt.show()
    
n=1000 #parametros
L= 4 #lambda 
p_acum = dist_acum_poisson(L,n) #Distribución de poisson
distribucion = Gen_distr_discreta(p_acum,n) #Distribución discreta
plot_histogram_discrete(distribucion,"Dist. de Poisson") #Histograma
